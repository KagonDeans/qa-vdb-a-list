# %% [markdown]
# Retrieval and Question Answering Exercise
#
# In this exercise, your goal is to utilize a vector database to attempt to retrieve relevant context to answer questions about Best Picture winners since 2000. Each question can be answered from the Wikipedia page of each movie.
#
# You have been provided a list of movies and links to their Wikipedia pages in the file best_picture_2000.csv.
#
# Build a vector database off of these Wikipedia pages which, given a query, can find potentially relevant context to answer the question.
#
# Then use a question-answering model from HugingFace to anwser the question.
#
# A list of question and answer pairs is given in QAs.csv, but feel free to add to it yourself.

# %%
import chromadb
from nltk.tokenize import sent_tokenize
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np

# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
# Import package
import wikipedia

# %%
client = chromadb.PersistentClient(path="./qa_vdb")
collection = client.get_collection("best_pictures")

# %%
movies = pd.read_csv('../data/best_picture_2000.csv')
movies = movies.reset_index()
movies
# Out:
#     index                                            title  \
# 0       0                                        Gladiator
# 1       1                                 A Beautiful Mind
# 2       2                                          Chicago
# 3       3    The Lord of the Rings: The Return of the King
# 4       4                              Million Dollar Baby
# 5       5                                            Crash
# 6       6                                     The Departed
# 7       7                           No Country for Old Men
# 8       8                              Slumdog Millionaire
# 9       9                                  The Hurt Locker
# 10     10                                The King's Speech
# 11     11                                       The Artist
# 12     12                                             Argo
# 13     13                                 12 Years a Slave
# 14     14  Birdman or (The Unexpected Virtue of Ignorance)
# 15     15                                        Spotlight
# 16     16                                        Moonlight
# 17     17                               The Shape of Water
# 18     18                                       Green Book
# 19     19                                         Parasite
# 20     20                                        Nomadland
# 21     21                                             CODA
# 22     22                Everything Everywhere All at Once
# 23     23                                      Oppenheimer
#
#                                                  link  year
# 0   https://en.wikipedia.org/wiki/Gladiator_(2000_...  2000
# 1   https://en.wikipedia.org/wiki/A_Beautiful_Mind...  2001
# 2   https://en.wikipedia.org/wiki/Chicago_(2002_film)  2002
# 3   https://en.wikipedia.org/wiki/The_Lord_of_the_...  2003
# 4   https://en.wikipedia.org/wiki/Million_Dollar_Baby  2004
# 5     https://en.wikipedia.org/wiki/Crash_(2004_film)  2005
# 6          https://en.wikipedia.org/wiki/The_Departed  2006
# 7   https://en.wikipedia.org/wiki/No_Country_for_O...  2007
# 8   https://en.wikipedia.org/wiki/Slumdog_Millionaire  2008
# 9       https://en.wikipedia.org/wiki/The_Hurt_Locker  2009
# 10  https://en.wikipedia.org/wiki/The_King%27s_Speech  2010
# 11    https://en.wikipedia.org/wiki/The_Artist_(film)  2011
# 12     https://en.wikipedia.org/wiki/Argo_(2012_film)  2012
# 13  https://en.wikipedia.org/wiki/12_Years_a_Slave...  2013
# 14       https://en.wikipedia.org/wiki/Birdman_(film)  2014
# 15     https://en.wikipedia.org/wiki/Spotlight_(film)  2015
# 16  https://en.wikipedia.org/wiki/Moonlight_(2016_...  2016
# 17   https://en.wikipedia.org/wiki/The_Shape_of_Water  2017
# 18    https://en.wikipedia.org/wiki/Green_Book_(film)  2018
# 19  https://en.wikipedia.org/wiki/Parasite_(2019_f...  2019
# 20            https://en.wikipedia.org/wiki/Nomadland  2020
# 9                                 The_Hurt_Locker
# 10                              The_King's_Speech
# 11                              The_Artist_(film)
# 12                               Argo_(2012_film)
# 13                        12_Years_a_Slave_(film)
# 14                                 Birdman_(film)
# 15                               Spotlight_(film)
# 16                          Moonlight_(2016_film)
# 17                             The_Shape_of_Water
# 18                              Green_Book_(film)
# 19                           Parasite_(2019_film)
# 20                                      Nomadland
# 21                               CODA_(2021_film)
# 22              Everything_Everywhere_All_at_Once
# 23                             Oppenheimer_(film)

# %%
movies['page']
# Out:
# 0                             Gladiator_(2000_film)
# 1                           A_Beautiful_Mind_(film)
# 2                               Chicago_(2002_film)
# 3     The_Lord_of_the_Rings:_The_Return_of_the_King
# 4                               Million_Dollar_Baby
# 5                                 Crash_(2004_film)
# 6                                      The_Departed
# 7                            No_Country_for_Old_Men
# 8                               Slumdog_Millionaire
# 9                                   The_Hurt_Locker
# 10                                The_King's_Speech
# 11                                The_Artist_(film)
# 12                                 Argo_(2012_film)
# 13                          12_Years_a_Slave_(film)
# 14                                   Birdman_(film)
# 15                                 Spotlight_(film)
# 16                            Moonlight_(2016_film)
# 17                               The_Shape_of_Water
# 18                                Green_Book_(film)
# 19                             Parasite_(2019_film)
# 20                                        Nomadland
# 21                                 CODA_(2021_film)
# 22                Everything_Everywhere_All_at_Once
# 23                               Oppenheimer_(film)
# Name: page, dtype: object

# %% [markdown]
# # Specify the title of the Wikipedia page
# wiki = wikipedia.page('Chicago_(2002_film)')
# # Extract the plain text content of the page
# text = wiki.content
# print(text)

# %% [markdown]
# # Import package
# import re# Clean text
# text = re.sub(r'==.*?==+', '', text)
# text = text.replace("\n", '')
# print(text)

# %% [markdown]
# # Using requests instead of wikipedia package: Specify url of the web page
# movie_wiki = requests.get('https://en.wikipedia.org/wiki/Chicago_(2002_film)')

# %% [markdown]
# movie_wiki

# %% [markdown]
# # Make a soup
# soup = BeautifulSoup(movie_wiki.text, 'html')

# %% [markdown]
# # Extract the plain text content from paragraphs
# paras = []
# for paragraph in soup.find_all('p'):
#     paras.append(str(paragraph.text))

# %%
# Extract text from paragraph headers
# heads = []
# for head in soup.find_all('span', attrs={'mw-headline'}):
#     heads.append(str(head.text))

# %%
# Interleave paragraphs & headers
# text = [val for pair in zip(paras, heads) for val in pair]
# text = ' '.join(text)

# %% [markdown]
# # Drop footnote superscripts in brackets
# paras = re.sub(r"\[.*?\]+", '', str(paras))

# %% [markdown]
# # Replace '\n' (a new line) with ''
# paras = paras.replace('\\n', '')
# print(paras)

# %%
def wiki_page(page):
    wiki = wikipedia.page(page, auto_suggest=False)
    return wiki

def wiki_content(wiki):    
    content=wiki.content
    return content

def wiki_text(content):        
    text = re.sub(r'==.*?==+', '', content)
    text = text.replace("\n", '')
    return text

def wiki_process(page):
    return wiki_text(wiki_content(wiki_page(page)))

# %%
wiki_process("The_King's_Speech")
# Out:
# 11  The Artist is a 2011 French comedy-drama film ...
# 12  Argo is a 2012 American biographical historica...
# 13  12 Years a Slave is a 2013 biographical drama ...
# 14  Birdman, stylized as BİRDMAN or (The Unexpecte...
# 15  Spotlight is a 2015 American biographical dram...
# 16  Moonlight is a 2016 American coming-of-age dra...
# 17  The Shape of Water is a 2017 Mexican-American ...
# 18  Green Book is a 2018 American biographical com...
# 19  Parasite (Korean: 기생충; RR: Gisaengchung) is a ...
# 20  Nomadland is a 2020 American drama film writte...
# 21  CODA is a 2021 coming-of-age comedy-drama film...
# 22  Everything Everywhere All at Once is a 2022 Am...
# 23  Oppenheimer is a 2023 epic biographical thrill...

# %%
collection.get(ids = ['0_1'])
# Out:
# {'ids': [],
#  'embeddings': None,
#  'metadatas': [],
#  'documents': [],
#  'uris': None,
#  'data': None}

# %%
def add_movie(movie):
    sentences = sent_tokenize(movie['text'])
    collection.add(
        documents = sentences,
        ids = [f'{movie["index"]}_{i}' for i in range(len(sentences))],
        metadatas = [{'movie': movie['title']}] * len(sentences)
    )

# %%
for _, row in tqdm(movies.iterrows()):
    add_movie(row)
# Out:
# 0it [00:00, ?it/s]

# %%
collection.get(ids = ['0_1'])
# Out:
# {'ids': ['0_1'],
#  'embeddings': None,
#  'metadatas': [{'movie': 'Gladiator'}],
#  'documents': ['It stars Russell Crowe, Joaquin Phoenix, Connie Nielsen, Tomas Arana, Ralf Möller, Oliver Reed (in his final role), Djimon Hounsou, Derek Jacobi, John Shrapnel, Richard Harris, and Tommy Flanagan.Crowe portrays Roman general Maximus Decimus Meridius, who is betrayed when Commodus, the ambitious son of Emperor Marcus Aurelius, murders his father and seizes the throne.'],
#  'uris': None,
#  'data': None}

# %%
query_text = "shot in"

results = collection.query(
    query_texts = [query_text],
    where={"movie": "The Hurt Locker"},
    n_results = 10
)

print(query_text)
print('\n -------- \n')
print('\n'.join(results['documents'][0]))
print('\n --------- \n')
# Out:
# shot in
#
#  --------
#
# Temperatures averaged 120 °F (49 °C) over the 44 days of shooting.
# "There were two-by-fours with nails being dropped from two-story buildings that hit me in the helmet, and they were throwing rocks.... We got shot at a few times while we were filming", Renner said.
# And in this way, the full impact of the Iraq war—at least as it was fought in 2004—becomes clear: American soldiers shot at Iraqi civilians even when, for example, they just happened to be holding a cell phone and standing near an IED."
# James and Sanborn rescue him, although Eldridge is shot in the leg.
# Describing the experience of filming in Jordan in the summer, he said, "It was so desperately hot, and we were so easily agitated.
# According to Renner, shooting the film in the Middle East contributed to this.
# Bigelow had wanted to film in Iraq, but the production security team could not guarantee their safety from snipers.Principal photography began in July 2007 in Jordan and Kuwait.
# While fixing the tire, they come under sniper fire.
# In 2020, the film was selected for preservation in the United States National Film Registry by the Library of Congress as being "culturally, historically, or aesthetically significant".During the second year of the Iraq War, a U.S. Army Explosive Ordnance Disposal team with Bravo Company identifies and attempts to destroy an improvised explosive device with a robot, but the wagon carrying the trigger charge breaks.
# The producer Greg Shapiro spoke about security concerns of filming in Jordan, "It was interesting telling people we were going to make the movie in Jordan because the first question everybody asked was about the security situation here.
#
#  ---------
